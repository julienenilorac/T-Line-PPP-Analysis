# %%
import pandas as pd

# %%
df = pd.read_excel('PPI World Bank - Energy.xlsx')

# %%
is_electricity = df['Subsector'] == 'Electricity'

# %%
is_electricity.value_counts()
# Out:
# True     4599
# False     542
# Name: Subsector, dtype: int64

# %%
df_electricity = df.query('Subsector == "Electricity"')

# %%
df_electricity['Project name'].nunique()
# Out:
# 3487

# %%
df_electricity_transmission = df.query('Subsector == "Electricity" & Segment == "Electricity transmission"')

# %%
df_electricity_transmission.groupby(['Subtype of PPI','Project name']).count()
# Out:
#                                                                                      Region  \
# Subtype of PPI                      Project name
# Build, operate, and transfer        AC Transmissao                                        1
#                                     ATE II Transmissora de Energia                        1
#                                     ATE III Transmissora de Energia                       1
#                                     ATE IV - Sao Mateus Transmissora de Energia           1
#                                     ATE Transmissora de Energia                           1
# ...                                                                                     ...
# Not Available                       Tropicalia Transmission Line                          1
# Partial                             Power Grid Company of Bangladesh                      1
#                                     Power Grid Corporation of India Limited (PGCIL)       2
# ...

# %%
newdf['Project name'].nunique()
# Out:
# 179
